# %% [markdown]
# # Week 11 Lab: Text Analytics - SOLUTION
#
# **Complete solution notebook with working code for all exercises.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)

print("✓ Libraries imported successfully!")

# %% [markdown]
# ---
#
# ## 🎯 Solution Complete!
#
# You've completed Week 11 Lab on Text Analytics.
#
# **Key Concepts Demonstrated:**
# - Preprocess text data
# - Analyze word frequencies
# - Perform basic sentiment analysis
# - Visualize text analytics results
#
# **Next Steps:**
# - Apply these techniques to your own projects
#
# ---
#
# *CMSC 178DA - Data Analytics | University of the Philippines Cebu*
