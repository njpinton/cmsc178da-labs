# %% [markdown]
# # Week 9 Lab: Clustering & Segmentation - SOLUTION
#
# **Complete solution notebook with working code for all exercises.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

pd.set_option('display.max_columns', None)
np.random.seed(42)

print("✓ Libraries imported successfully!")

# %% [markdown]
# ---
#
# ## 🎯 Solution Complete!
#
# You've completed Week 9 Lab on Clustering & Segmentation.
#
# **Key Concepts Demonstrated:**
# - Implement K-means clustering
# - Use elbow method to find optimal K
# - Perform customer/regional segmentation
# - Interpret cluster characteristics
#
# **Next Steps:**
# - Apply these techniques to your own projects
#
# ---
#
# *CMSC 178DA - Data Analytics | University of the Philippines Cebu*
