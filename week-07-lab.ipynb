# %% [markdown]
# # Week 7 Lab: Regression Modeling
#
# **Estimated Time:** 30-60 minutes
# **Objective:** Build and evaluate linear regression models using Philippine data.
#
# In this lab, you will:
# - Implement linear regression with scikit-learn
# - Evaluate models using RMSE and R²
# - Make predictions on new data
# - Interpret regression coefficients
#
# ---

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

pd.set_option('display.max_columns', None)
np.random.seed(42)

print("✓ Libraries imported successfully!")

# %% [markdown]
# ---
# ## Lab Exercises
#
# **Context:** Philippine housing prices or salary data
#
# TODO: Complete the exercises following the format from Weeks 1-3.
#
# **Key Topics:**
# - Implement linear regression with scikit-learn
# - Evaluate models using RMSE and R²
# - Make predictions on new data
# - Interpret regression coefficients

# %% [markdown]
# ---
# ## Reflection Questions
#
# 1. How can these techniques be applied to Philippine data?
#
# 2. What insights did you gain from this lab?
#
# 3. What challenges did you face and how did you overcome them?

# %% [markdown]
# ### Your Answer to Question 1:
#
# [Your answer here]

# %% [markdown]
# ### Your Answer to Question 2:
#
# [Your answer here]

# %% [markdown]
# ### Your Answer to Question 3:
#
# [Your answer here]

# %% [markdown]
# ---
#
# ## 🎯 Congratulations!
#
# You've completed Week 7 Lab on Regression Modeling.
#
# **Key Skills Practiced:**
# - Implement linear regression with scikit-learn
# - Evaluate models using RMSE and R²
# - Make predictions on new data
# - Interpret regression coefficients
#
# **Remember:** Check the **solution notebook** if you need help!
#
# **Next Steps:**
# - Practice with real Philippine datasets
# - Explore advanced techniques
# - Move on to Week 8 lab
#
# ---
#
# *CMSC 178DA - Data Analytics | University of the Philippines Cebu*
