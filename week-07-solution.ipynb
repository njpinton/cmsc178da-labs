# %% [markdown]
# # Week 7 Lab: Regression Modeling - SOLUTION
#
# **Complete solution notebook with working code for all exercises.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

pd.set_option('display.max_columns', None)
np.random.seed(42)

print("✓ Libraries imported successfully!")

# %% [markdown]
# ---
#
# ## 🎯 Solution Complete!
#
# You've completed Week 7 Lab on Regression Modeling.
#
# **Key Concepts Demonstrated:**
# - Implement linear regression with scikit-learn
# - Evaluate models using RMSE and R²
# - Make predictions on new data
# - Interpret regression coefficients
#
# **Next Steps:**
# - Apply these techniques to your own projects
#
# ---
#
# *CMSC 178DA - Data Analytics | University of the Philippines Cebu*
